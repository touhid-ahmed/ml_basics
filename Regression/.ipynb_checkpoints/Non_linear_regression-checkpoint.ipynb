# %% [markdown]
# #  **Non-Linear Regression**
#
# ### **Import the Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### **Read the Data using Pandas Dataframe**

# %%
rd = pd.read_csv("china_gdp.csv")
rd.head(5)
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10

# %% [markdown]
# ### **Plot the relation between GDP and Year**

# %%
# plt.figure(figsize=(8,5))
x_data = (rd["Year"].values)
y_data = (rd ["Value"].values)
plt.plot(x_data, y_data, 'bo')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()

# %% [markdown]
# ### **Plotting the Sigmoid Function**

# %%
X = np.arange(-5, 5, 0.1)
Y = 1/(1+ np.exp(-X))
plt.plot(X,Y)
plt.ylabel('Dependent Variable')
plt.xlabel('Indepdendent Variable')
plt.show()

# %%
def sigmoid(x, a, b):
    y = 1 / (1 + np.exp(-a*(x-b)))
    return y

# %% [markdown]
# ### **Plotting Sigmoid Function over a specific value**

# %%
a = 0.10
b = 1990.0
Y_pred = sigmoid(x_data, a , b)

plt.plot(x_data, Y_pred*15000000000000.)
plt.plot(x_data, y_data, 'ro')

# %% [markdown]
# ### **Normalize the x and y values**

# %%
xdata =x_data/max(x_data)
ydata =y_data/max(y_data)

# %% [markdown]
# ### **Get the optimal parameters for the x and y values**

# %%
from scipy.optimize import curve_fit
popt, pcov = curve_fit(sigmoid, xdata, ydata)
#print the final parameters
print(" a = %f, b = %f" % (popt[0], popt[1]))
# Out:
#  a = 690.451711, b = 0.997207

# %% [markdown]
# ### **Plotting the model**

# %%
x = np.linspace(1960, 2015, 55)
x = x/max(x)
plt.figure(figsize=(8,5))
y = sigmoid(x, popt[0], popt[1])
plt.plot(xdata, ydata, 'ro', label='data')
plt.plot(x,y, linewidth=3.0, label='fit')
plt.legend(loc='best')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### **Create test and train set**

# %%
msk = np.random.rand(len(rd)) < 0.8
train_x = xdata[msk]
test_x = xdata[~msk]
train_y = ydata[msk]
test_y = ydata[~msk]

# %% [markdown]
# ### **Build the model using train set**

# %%
popt, pcov = curve_fit(sigmoid, train_x, train_y)

# %% [markdown]
# ### **Model Prediction using test set**

# %%
y_hat = sigmoid(test_x, popt[0], popt[1])

# %% [markdown]
# ### **Evaluation**

# %%
from sklearn.metrics import r2_score

print("Mean absolute error: %.2f" % np.mean(np.absolute(y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((y_hat - test_y) ** 2))
print("R2-score: %.2f" % r2_score(y_hat , test_y) )
# Out:
# Mean absolute error: 0.03
# Residual sum of squares (MSE): 0.00
# R2-score: 0.96
